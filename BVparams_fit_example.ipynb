# %% [markdown]
# # Bond Valence Parameter Fitting Example
#
# **Author:** Chunhui Li (lchwestlife@gmail.com)
#
# This notebook demonstrates how to fit bond valence parameters $R_0$ and $B$ for cation-anion pairs using Materials Project data.
#
# ## Prerequisites
#
# Before running this notebook, ensure you have:
# 1. Installed all dependencies: `pip install -r requirements.txt`
# 2. A [Materials Project API key](https://materialsproject.org/api#api-key) (free registration)

# %% [markdown]
# ## Setup
#
# Import the `BondValenceProcessor` class:

# %%
from bond_valence_processor import BondValenceProcessor

# %% [markdown]
# ## Configure Parameters
#
# Set your Materials Project API key and choose which cation-anion systems to fit:
#
# - **`cations`** - list of cation elements to process (e.g., `['Li', 'Na', 'K']`)
# - **`anions`** - list of anion elements to process (e.g., `['O', 'Cl', 'F']`)
# - **`my_api_key`** - your [Materials Project API key](https://materialsproject.org/api#api-key)
# - **`algos`** - optimization algorithms to use (`'shgo'`, `'brute'`, `'diff'`, `'dual_annealing'`, `'direct'`)

# %%
import os

cations = ['Li']  # a list of cation species
anions = ['O']    # a list of anion species
my_api_key = os.environ["MP_API_KEY"]
algos = ['shgo']  # a list of optimization algorithms to use. Choose from 'shgo', 'differential_evolution', 'dual_annealing', 'basinhopping', 'brute'

# %% [markdown]
# ## Run
#
# Initialize the processor and fit bond valence parameters for each cation-anion system. Results will be saved to the `res/` directory.

# %%
processor = BondValenceProcessor(my_api_key, algos, cations, anions)

for cation in cations:
    for anion in anions:
        processor.process_cation_system(cation, anion)
# Out:
# Processing Li-O system...
# Retrieving SummaryDoc documents:   0%|          | 0/6673 [00:00<?, ?it/s]
# Getting possible species: 100%|██████████| 6673/6673 [00:00<00:00, 2428511.11it/s]
# Retrieving BondingDoc documents:   0%|          | 0/6518 [00:00<?, ?it/s]
# Processing Li-O materials:   2%|▏         | 157/6518 [01:17<52:15,  2.03it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       3 for cation in cations:
#       4     for anion in anions:
# ----> 5         processor.process_cation_system(cation, anion)
#
# File ~/Projects/github/ScreenedBondValence/bond_valence_processor.py:78, in BondValenceProcessor.process_cation_system(self, cation, anion)
#      75 results.update(self._load_previous_results(res_dir))
#      77 # Process materials
# ---> 78 self._process_materials(
#      79     bonds_docs=bonds_docs,
#      80     results=results,
#      81     res_dir=res_dir,
#      82     cation=cation,
#      83     anion=anion
#      84 )
#      86 # Save final results
#      87 self._save_results(res_dir, results['sij'], results['charges'])
#
# File ~/Projects/github/ScreenedBondValence/bond_valence_processor.py:151, in BondValenceProcessor._process_materials(self, bonds_docs, results, res_dir, cation, anion)
#     148     continue
#     150 # Compute Sij values
# --> 151 sij_data = solver.get_sij(
#     152     material.material_id,
#     153     material.structure_graph.structure,
#     154     material.structure_graph
#     155 )
#     157 # Store results
#     158 results['sij'][material.material_id] = sij_data[0]
#
# File ~/Projects/github/ScreenedBondValence/BVparams_search.py:311, in TheoreticalBondValenceSolver.get_sij(self, matID, struct, graph)
#     308 equations_val_sum, bond_vars, bondL = self.get_eqs_from_valence_sum_rule(struct, graph, dict_charge)
#     309 equations_cycle = self.get_eqs_from_loops(struct, graph, dict_charge)
# --> 311 sijs = self.solve_sij(bond_vars, equations_val_sum + equations_cycle)
#     312 return sijs, list(bond_vars), bondL, dict_charge
#
# File ~/Projects/github/ScreenedBondValence/BVparams_search.py:230, in TheoreticalBondValenceSolver.solve_sij(self, variables, equations)
#     228 symbols_list = sp.symbols(variables)
#     229 eqs = [sp.Eq(sp.sympify(eq[0]), eq[1]) for eq in equations]
# --> 230 solution = sp.solve(eqs, symbols_list)
#     232 if not solution or any(isinstance(v, sp.Add) for v in solution.values()):
#     233     return None
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SBV/lib/python3.11/site-packages/sympy/solvers/solvers.py:1170, in solve(f, *symbols, **flags)
#    1168         solution = _solve(f[0], *symbols, **flags)
#    1169 else:
# -> 1170     linear, solution = _solve_system(f, symbols, **flags)
#    1171 assert type(solution) is list
#    1172 assert not solution or type(solution[0]) is dict, solution
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SBV/lib/python3.11/site-packages/sympy/solvers/solvers.py:1784, in _solve_system(exprs, symbols, **flags)
#    1782             E.append((e1, e2))
#    1783 G = V, E
# -> 1784 subexprs = connected_components(G)
#    1785 if len(subexprs) > 1:
#    1786     subsols = []
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/SBV/lib/python3.11/site-packages/sympy/utilities/iterables.py:1123, in connected_components(G)
#    1121 E_undirected = []
#    1122 for v1, v2 in E:
# -> 1123     E_undirected.extend([(v1, v2), (v2, v1)])
#    1124 return strongly_connected_components((V, E_undirected))
#
# KeyboardInterrupt:
